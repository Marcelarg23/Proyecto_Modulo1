# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Brisa Fernanda González Arredondo, Cristina Lobera de la Mora, Ana Marcela Ramos Gutiérrez.
#
# **Fecha:** 24 de marzo del 2020.
#
# **Expedientes** : 714993, 714997, 714580.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Proyecto Módulo 2

# %% [markdown]
# ___
# ## 1. Descripción del proyecto.
#
# ### 1.1 Título del trabajo.
# > Coronavirus: ¿Por qué es importante aplanar la curva?
#
# ### 1.2 Objetivos.
#
# > #### Objetivo general.
#
# >  - Generar un modelo que nos permita hacer estimaciones en futuro cercano sobre la situación de la pandemia del COVID-19 en Estados Unidos.
#
# > #### Objetivos específicos.
#
# >  - Simular el número de casos confirmados, recuperaciones y muertes de COVID-19 en Estados Unidos.
#
# >  - Obtener una distribución para los datos de casos confirmados, recuperaciones y muertes de COVID-19 en los Estados Unidos.
#
# >  - Estimar a partir de los datos obtenidos de E.E.U.U., el número de casos que se presentarán en un tiempo determinado.

# %% [markdown]
# ### 1.3 Definición del problema.
#
# > Actualmente, la Organización Mundial de la Salud (OMS) clasificó al COVID-19 como una pandemia. Esta, es una enfermedad respiratoria causada por un nuevo coronavirus que se identificó por primera vez en Wuhan, China. La situación emergente que se vive hoy en día está cambiando de manera rápida y ha sido clasificada como pandemia debido a que es un virus epidémico que se esparce con facilidad en varios países del mundo de manera simultánea. A partir de marzo del 2020 los casos de personas con este padecimiento han aumentado de manera exponencial a un grado en el que dificulta más su control, y de la mano va el número de muertes presentadas a causa del esparcimiento del virus.
# A parte de las consecuencias que se han ido desarrollando en el sector salud a causa del COVID-19, el impacto en la economía a nivel mundial también es uno de los principales sectores que se verá afectado por el coronavirus. El impacto económico se verá reflejado principalmente en la producción y en la interrupción de la cadena de suministro y del mercado y en las repercusiones financieras en las empresas y los mercados financieros. Actualmente, en el mercado bursátil ha habido una fuerte caída en las acciones globales, los bancos centrales se encuentran en la necesidad de recortar las tasas de interés para fortalecer sus economías, más de 100 países impusieron restricciones de viaje lo cual afecta al sector del turismo, el precio del petróleo esta en su nivel más bajo desde el 2001, entre muchas otras situaciones.
#
# > Estados Unidos, una de las potencias mundiales, ha sido hasta ahora el país con mayores casos de COVID-19 y se encuentran en la fase de aceleración de la pandemia. Es la primera economía del mundo por volumen de PIB, por lo tanto, el impacto que tiene en el resto de las economías es demasiado grande. Las principales razones por las que se ha expandido exponencialmente en Estados Unidos, están descritas en la siguiente noticia y son los motivos por los que la curva ha incrementado, por lo que son puntos  a tomar a consideración para aplanar la curva.
# https://www.eluniversal.com.mx/mundo/coronavirus-por-que-el-covid-19-tuvo-un-gran-impacto-en-eu
#
# > Por otra parte, en México algunos estados tomaron precauciones guiandose por las experencias de otros países como Italia o EEUU, sin embargo para el Presidente no fue de mucha importancia este tema, es por eso que el país se declaró en la tercera fase y la cuarentena o el aislamiento se recorrió hasta el 30 de Mayo. A pesar de esto, todavía hay gente que continua en las calles en sus rutinas diarias, es por eso que ahora se aplicó un decreto de que los ciudadanos deberán usar cubrebocas forzosamente para salir. De igual manera, se está llevando a cabo un plan de desarrollo para aquellas familias cuya economía depende de empresas o negocios que no se encuentran laborando.
#
# > El objetivo de este proyecto es analizar los datos obtenidos de los Estados Unidos y con ello, simular y estimar posibles escenarios sobre los casos activos, las recuperaciones y las muertes que habrá a causa del COVID-19 en México en un futuro cercano.
#
# Hablar mas de estados Unidos, lo que se preveé, como actúa el gobierno, hablar de los estudios que se hacen por ejemplo la generación, hablar de la población o lo que sea relevante del tema pero en estados unidos.
# Agregar citas y las referencias al fianl

# %% [markdown]
# ### 1.4 Nodos y variables que se decidieron simular y por qué
# > Para llevar a cabo el proyecto, primeramente se obtienen los datos necesarios, en este caso, se obtuvieron el número de casos activos de cornavirus en Estados unidos, el número de recuperaciones y el número de muertes por día. A partir de la información recabada, se obtiene el incremento de cada variable y de esta manera se calcula un porcentaje de cambio de cada día y se grafica ese cambio (3 gráficas de cambio; Casos activos, recuperaciones y muertes). Posteriormente hacer una simulación del comportamiento aleatorio en el aumento de cada caso para México en un tiempo determinado utilizando como base, como fue el comportamiento de EEUU. A continuación se obtienen distribuciones de cambio y se grafican para obtener las estimaciones del comportamiento de la pandemia en México.
#
# ![Diagram.png](attachment:Diagram.png)

# %% [markdown]
# ### 1.5 Definición de hipótesis y supuestos.
# > #### Supuestos
#
# > 1. Los países son independientes uno del otro; posición y continente son irrelevantes.
#
# > 2. El clima no afecta en lo absoluto al virus.
#
# > 3. No existe una cura.
#
# > #### Hipótesis
#
# > H1. El avance de la pandemia en Estados Unidos será parecido al comportamiento del modelos.
#
# > H2. Las muertes estimadas en Estados Unidos podrían aumentar debido a la saturación de servicios médicos.
#
# > H3. Los datos reales de Estados Unidos serán menores a las estimaciones por la falta de información verídica y/o el ocultamiento de la misma.

# %% [markdown]
# ### 1.6 Obtención de bases de datos
# > Para este proyecto se buscó una base de datos que englomerara toda la información requerida sobre el coronavirus en Estados Unidos, la base de datos seleccionada se tomará de la siguiente página web:
#
# > https://datosmacro.expansion.com/otros/coronavirus/usa

# %% [markdown]
# ### 1.7 Visualización de resultados de simulación.
# > Se deben simular al menos 4  "nodos" o "escenarios" en tu problema. Para la segunda entrega debes haber elaborado un programa que simule dos de ellos, los primeros dos de tu diagrama.
# > Para la entrega final deben de tener los 4 nodos con todas sus simulaciones.

# %%
# %matplotlib inline

import warnings
import numpy as np 
import pandas as pd 
import scipy.stats as st 
import statsmodels as sm 
import matplotlib 
import matplotlib.pyplot as plt 
from sklearn.neighbors import KernelDensity 
from scipy import optimize 
from scipy.stats import gaussian_kde 
from scipy.stats import loglaplace 
from statsmodels.nonparametric.kde import KDEUnivariate 
from statsmodels.nonparametric.kernel_density import KDEMultivariate 
from scipy.stats.distributions import norm 
from sklearn.model_selection import GridSearchCV

# %%
# Importar base de datos 
Data = pd.read_csv('../ProyectoConjunto_CLobera_BFGonzalez_AMRamos/DataBase.csv')
Data = Data.fillna(0)

# Mostrar info
PData = Data.head().append(Data.tail())
PData
# Out:
#        Fecha  Activos  Confirmados  Incremento Confirmados  Recuperados  \
# 0   22/01/20        1            1                       1            0
# 1   23/01/20        1            1                       0            0
# 2   24/01/20        2            2                       1            0
# 3   25/01/20        2            2                       0            0
# 4   26/01/20        5            5                       3            0
# 78  09/04/20   419549       461437                   32385        25410
# 79  10/04/20   449159       496535                   35098        28790
# 80  11/04/20   474663       526396                   29861        31270
# 81  12/04/20   500305       555313                   28917        32988
# 82  13/04/20   513608       580619                   25306        43482
#
#     Incremento Recuperados  Muertos  Incremento Muertos
# 0                        0        0                   0
# 1                        0        0                   0
# ...

# %%
PConfirmados = [0]+[0 if np.array(Data["Incremento Confirmados"])[i-1] == 0 
                else ((np.array(Data["Incremento Confirmados"])[i] - np.array(Data["Incremento Confirmados"])[i-1]) / np.array(Data["Incremento Confirmados"])[i-1]) for i in range(1,len(Data))]
Data["%Confirmados"] = pd.Series(PConfirmados)

PRecuperados = [0]+[0 if np.array(Data["Incremento Recuperados"])[i-1] == 0 
                else ((np.array(Data["Incremento Recuperados"])[i] - np.array(Data["Incremento Recuperados"])[i-1]) / np.array(Data["Incremento Recuperados"])[i-1]) for i in range(1,len(Data))]
Data["%Recuperados"] = pd.Series(PRecuperados)

PMuertos = [0]+[0 if np.array(Data["Incremento Muertos"])[i-1] == 0 
                else ((np.array(Data["Incremento Muertos"])[i] - np.array(Data["Incremento Muertos"])[i-1]) / np.array(Data["Incremento Muertos"])[i-1]) for i in range(1,len(Data))]
Data["%Muertos"] = pd.Series(PMuertos)

PData = Data.head().append(Data.tail())
PData
# Out:
#        Fecha  Activos  Confirmados  Incremento Confirmados  Recuperados  \
# 0   22/01/20        1            1                       1            0
# 1   23/01/20        1            1                       0            0
# 2   24/01/20        2            2                       1            0
# 3   25/01/20        2            2                       0            0
# 4   26/01/20        5            5                       3            0
# 78  09/04/20   419549       461437                   32385        25410
# 79  10/04/20   449159       496535                   35098        28790
# 80  11/04/20   474663       526396                   29861        31270
# 81  12/04/20   500305       555313                   28917        32988
# 82  13/04/20   513608       580619                   25306        43482
#
#     Incremento Recuperados  Muertos  Incremento Muertos  %Confirmados  \
# 0                        0        0                   0      0.000000
# ...

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True, figsize=(20,6))
ax1.hist(PConfirmados, density = True, color = "y")
ax2.hist(PRecuperados, density = True, color = "mediumturquoise")
ax3.hist(PMuertos, density = True, color = "teal")
ax1.set_title("% Casos Confirmados")
ax2.set_title("% Casos Recuperados")
ax3.set_title("% Casos Muertos")
# Out:
# Text(0.5, 1.0, '% Casos Muertos')

# %%
def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = kde_skl.score_samples(x_grid[:, np.newaxis])
    return np.exp(log_pdf)
print( "Package Versions:")
import sklearn; print( "  scikit-learn:", sklearn.__version__)
import scipy; print ("  scipy:", scipy.__version__)
import statsmodels; print( "  statsmodels:", statsmodels.__version__)
# Out:
# Package Versions:
#   scikit-learn: 0.21.2
#   scipy: 1.3.0
#   statsmodels: 0.10.0

# %%
type(PConfirmados)
# Out:
# list

# %%
x_grid = np.linspace(-4.5, 3.5, 1000)
x = np.array(PConfirmados)

grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 5, 50)},
                    cv=20)
grid.fit(x[:, None])
print(grid.best_params_)
# Out:
# {'bandwidth': 0.30000000000000004}
# /Users/marce/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))
plt.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
plt.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
plt.legend(loc='upper left')
plt.xlim(-2.5, 3.5);

# %%
x = np.array(PRecuperados)

grid.fit(x[:, None])
print(grid.best_params_)
# Out:
# {'bandwidth': 2.0}
# /Users/marce/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))
plt.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
plt.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
plt.legend(loc='upper left')
plt.xlim(-4.5, 3.5);

# %%
x = np.array(PMuertos)

grid.fit(x[:, None])
print(grid.best_params_)
# Out:
# {'bandwidth': 0.5}
# /Users/marce/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))
plt.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
plt.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
plt.legend(loc='upper left')
plt.xlim(-2.5, 3.5);

# %%
def best_fit_distribution2(data, bins=200, ax=None):
    """Model data by finding best fit distribution to data"""

    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0
    
    
# Distributions to check
#    DISTRIBUTIONS = [        
#        st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
#        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
#        st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
#        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
#        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
#        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
#        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
#        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
#        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
#        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
#    ]

    DISTRIBUTIONS = [st.alpha, st.beta, st.chi,st.chi2, st.gamma, st.norm, st.logistic,st.loggamma,
                     st.loglaplace,st.lognorm, st.t, st.triang]
    
    
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf
    
    #Estimamos parametros
    for distribution in DISTRIBUTIONS:
    
    # aplicamos la funcion fit a los datos
        try:
            
        
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')
                
                params = distribution.fit(data)
                
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]
                
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))
                
                
                # Verificamos si le queda mejor la distribucion a los datos
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse
                
        except Exception:
            pass

    return (best_distribution.name, best_params)

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# Create models from data
def best_fit_distribution(data, bins=200, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
##    DISTRIBUTIONS = [        
#        st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
#        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
#        st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
#        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
#        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
#        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
#        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
#        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
#        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
#        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
#    ]

    DISTRIBUTIONS = [st.alpha, st.beta, st.chi,st.chi2, st.gamma, st.norm, st.logistic,st.loggamma,
                    st.loglaplace,st.lognorm, st.t, st.triang]

    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:

        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params)

def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf



# Load data from statsmodels datasets
data = pd.Series(PConfirmados)

# Plot for comparison
plt.figure(figsize=(12,8))
ax = data.plot(kind='hist', bins=20, normed=True, alpha=0.5)
# Save plot limits
dataYLim = ax.get_ylim()

# Find best fit distribution
best_fit_name, best_fit_params = best_fit_distribution(data, 200, ax)
best_dist = getattr(st, best_fit_name)

# Update plots
ax.set_ylim(dataYLim)
ax.set_title(u'Casos confirmados\n All Fitted Distributions')
ax.set_xlabel(u'Porcentaje de cambio de los casos')
ax.set_ylabel('Frecuencia')

# Make PDF with best params 
pdf = make_pdf(best_dist, best_fit_params)

# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True)
data.plot(kind='hist', bins=50, normed=True, alpha=0.5, label='Data', legend=True, ax=ax)

param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_params)])
dist_str = '{}({})'.format(best_fit_name, param_str)

ax.set_title(u'Casos confirmados\n All Fitted Distributions: '+ dist_str)
ax.set_xlabel(u'Porcentaje de cambio de los casos')
ax.set_ylabel('Frecuencia')
# Out:
# /Users/marce/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1344: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
# /Users/marce/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1344: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
# Text(0, 0.5, 'Frecuencia')

# %%
N = 10**4

# %%
BF1 = best_fit_distribution2(PConfirmados, bins=200, ax=None)
NA1 = eval(BF1[0]).rvs(BF1[1][0],BF1[1][1],BF1[1][2], size = N)
NA1.mean()
# Out:
# 0.07520176923942645

# %%
BF2 = best_fit_distribution2(PRecuperados, bins=200, ax=None)
NA2 = eval(BF2[0]).rvs(BF2[1][0],BF2[1][1],BF2[1][2], size = N)
NA2.mean()
# Out:
# 0.11792434448851549

# %%
BF3 = best_fit_distribution2(PMuertos, bins=200, ax=None)
NA3 = eval(BF3[0]).rvs(BF3[1][0],BF3[1][1],BF3[1][2], size = N)
NA3.mean()
# Out:
# 0.051965031752973116

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True, figsize=(20,6))
ax1.hist(NA1, density = True, color = "y")
ax2.hist(NA2, density = True, color = "mediumturquoise")
ax3.hist(NA3, density = True, color = "teal")
ax1.set_title("Distribución estimada cambio Confirmados")
ax2.set_title("Distribución estimada cambio Recuperados")
ax3.set_title("Distribución estimada cambio Muertos")
# Out:
# Text(0.5, 1.0, 'Distribución estimada cambio Muertos')

# %%
import statsmodels.api as sm 
loc=-1.9486806
scale=1.94868
x = np.array(PConfirmados)
sm.qqplot(x, dist='loglaplace', distargs=(4.94,),loc=loc,scale=scale, line='45')
plt.show()
# Out:
# /Users/marce/anaconda3/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:4339: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# /Users/marce/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2381: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu

# %%
import statsmodels.api as sm 
loc=-1.469045
scale=1.469045
x = np.array(PRecuperados)
sm.qqplot(x, dist='loglaplace', distargs=(3.495383,),loc=loc,scale=scale, line='45')
plt.show()
# Out:
# /Users/marce/anaconda3/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:4339: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# /Users/marce/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2381: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu

# %%
import statsmodels.api as sm 
loc=-1.316267
scale=1.316267
x = np.array(PMuertos)
sm.qqplot(x, dist='loglaplace', distargs=(4.995729,),loc=loc,scale=scale, line='45')
plt.show()
# Out:
# /Users/marce/anaconda3/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:4339: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# /Users/marce/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2381: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu

# %%
#Crear estimaciones para un futuro cercano
Data.tail()
# Out:
#        Fecha  Activos  Confirmados  Incremento Confirmados  Recuperados  \
# 78  09/04/20   419549       461437                   32385        25410
# 79  10/04/20   449159       496535                   35098        28790
# 80  11/04/20   474663       526396                   29861        31270
# 81  12/04/20   500305       555313                   28917        32988
# 82  13/04/20   513608       580619                   25306        43482
#
#     Incremento Recuperados  Muertos  Incremento Muertos  %Confirmados  \
# 78                    1851    16478                1783     -0.013525
# 79                    3380    18586                2108      0.083773
# 80                    2480    20463                1877     -0.149211
# 81                    1718    22020                1557     -0.031613
# 82                   10494    23529                1509     -0.124875
#
#     %Recuperados  %Muertos
# 78      0.030624 -0.096300
# 79      0.826040  0.182277
# ...

# %%
Abr14C = Data["Confirmados"][82] + (Data["Incremento Confirmados"][82] * (1+NA1.mean()))
Abr15C = Abr14C + ((Data["Incremento Confirmados"][82] * (1+NA1.mean()) * (1+NA1.mean())))
Abr16C = Abr15C + ((Data["Incremento Confirmados"][82] * (1+NA1.mean()) * (1+NA1.mean())* (1+NA1.mean())))

Abr14C, Abr15C, Abr16C
# Out:
# (607828.0559723729, 637083.2810932029, 668538.5509026169)

# %%
Abr14R = Data["Recuperados"][82] + (Data["Incremento Recuperados"][82] * (1+NA2.mean()))
Abr15R = Abr14R + ((Data["Incremento Recuperados"][82] * (1+NA2.mean()) * (1+NA2.mean())))
Abr16R = Abr15R + ((Data["Incremento Recuperados"][82] * (1+NA2.mean()) * (1+NA2.mean())* (1+NA2.mean())))

Abr14R, Abr15R, Abr16R
# Out:
# (55213.49807106248, 68328.42536202329, 82989.9218567852)

# %%
Abr14R = Data["Recuperados"][82] + (Data["Incremento Recuperados"][82] * (1+NA2.mean()))
Abr15R = Data["Recuperados"][82] + ((Data["Incremento Recuperados"][82] * (1+NA2.mean()) * (1+NA2.mean())))
Abr16R = Data["Recuperados"][82] + ((Data["Incremento Recuperados"][82] * (1+NA2.mean()) * (1+NA2.mean())* (1+NA2.mean())))

Abr14R, Abr15R, Abr16R
# Out:
# (55213.49807106248, 56596.927290960804, 58143.4964947619)

# %%
Abr14M = Data["Muertos"][82] + (Data["Incremento Muertos"][82] * (1+NA3.mean()))
Abr15M = Abr14M + ((Data["Incremento Muertos"][82] * (1+NA3.mean()) * (1+NA3.mean())))
Abr16M = Abr15M + ((Data["Incremento Muertos"][82] * (1+NA3.mean()) * (1+NA3.mean())* (1+NA3.mean())))

Abr14M, Abr15M, Abr16M
# Out:
# (25116.415232915235, 26786.320548814067, 28543.002547478038)

# %% [markdown]
# ![Captura%20de%20pantalla%202020-04-20%20a%20la%28s%29%2001.45.47.png](attachment:Captura%20de%20pantalla%202020-04-20%20a%20la%28s%29%2001.45.47.png)

# %%
#Error relativo 14/Abr/20
print((((607828-607670)/607670)*100), "%")
# Out:
# 0.026000954465417083 %

# %% [markdown]
# ### 1.8 Conclusiones.
#
# Para concluir, se generó un modelo con el cual se pudieron crear estimaciones futuras a partir de las fechas dadas. Además, se obtuvo el número de casos confirmados, recuperaciones y muertes de COVID-19 en Estados Unidos para los días 14, 15 y 16 de abril del 2020.
#
# En cuanto a los casos confirmados, se pudo observar que el comportamiento de las estimaciones fue practicamente idéntico a la realidad con un error relativo de 0.026% para el día 14 de abril del 2020. Esto nos indica que los casos confirmados efectivamente siguen la distribución generada en el futuro cercano, en palabras colquiales, en este momento los casos confirmados se comportan de esta manera. Por otra parte, la estimación obtuvo valores mayores a los reales, lo que nos puede indicar que puede existir una falta de información verídica y/o el ocultamiento de la misma o incluso un déficit en el registro de casos de la población debido a la falta de realización de pruebas, lo cual es un problema conocido en los Estados Unidos.
#
# Para los casos de recuperaciones, se realizaron dos tipos de estimaciones, en la primera se realizó un modelo recursivo donde se calculó el número de casos para el día siguiente y a partir de ese valor se hacía un nuevo cálculo para otro día y así sucesivamente, mientras que en el segundo caso se tomaron las recuperaciones como constantes con el fin de reducir la volatilidad del cálculo; sin embargo, ambas estimaciones resultaron alejadas a los valores reales, esto puede deberse a diversos factores como lo son las malas políticas de salud que se están tomando y criticando en Estados Unidos, así como los problemas ya existentes en su población (sobrepeso, hipertensión, etc.).
#
# Por otra parte, las muertes estimadas resultaron ser menores a las reales por lo tanto se rechaza nuestra hipótesis 2 y esto se puede explicar a partir de que los hospitales se están saturando, el personal médico es insuficiente y no existe un tratamiento para combatir este virus, lo que puede generar un cambio abrupto en la manera en que se distribuyen los datos, y el modelo actual podría resultar inadecuado para explicar los cambios.
#
# Finalmente, podemos decir que nuestro modelo tuvo mejores resultados en las estimaciones de los casos confirmados debido a que el comportamiento de la población no varía tanto, es decir, existen estratos de la sociedad que se cuidan y toman precauciones, cumplen la cuarentena, mientras que otra parte de la población actúa indiferente ante las recomendaciones de instituciones de la salud, sin embargo, el comportamiento de las muertes y las recuperaciones resulta ser más volátil ya que las variables que los afectan son más cambiantes y pueden generar un cambio en la distribución que explica los datos.
#
# ### 1.9 Referencias.
# > Citar (en formato APA) la bibliografía utilizada.

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
